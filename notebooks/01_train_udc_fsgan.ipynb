# %% [markdown]
# # Train UDC-FSGAN
# This notebook trains the main model on CelebA-HQ.

# %%
# !pip install -r requirements.txt

# %%
from training.train_udc_fsgan import main
# Run from CLI in Colab or adapt the config path here.
